# %%
import requests
import json
import time
import pprint

# %% [markdown]
# ### Посмотреть документацию к API GitHub, разобраться как вывести список репозиториев для конкретного пользователя, сохранить JSON-вывод в файле *.json.

# %%
url = 'https://api.github.com'
user='Goccman'

# %%
r = requests.get(f'{url}/users/{user}/repos')

# %%
with open('data.json', 'w') as f:
    json.dump(r.json(), f)

# %%
for i in r.json():
    print(i['name'])
# Out:
# -3592HW
# Android
# collecting_processing_data_from_Internet_DS_GB
# GB-AndroidLesson2
# GB_C_Sharp
# helloWorl
# helloWorld
# Python_Libraries_DS_GB
# test

# %% [markdown]
# ### Изучить список открытых API (https://www.programmableweb.com/category/all/apis). Найти среди них любое, требующее авторизацию (любого типа). Выполнить запросы к нему, пройдя авторизацию. Ответ сервера записать в файл.

# %%
from pprint import pprint
params = {
    'lang' : 'ru',
    'appid' : 'aff0bfe1082363975e5e56ad3fb3c497',
    'q' : 'Omsk',
    'units' : 'metric'

}
url = 'https://api.openweathermap.org/data/2.5/weather'
response = requests.get(url =url, params = params)
print(response.status_code)
print()
print('Получен результат')
pprint(response.json())

with open('data_weather.json', 'w') as f:
    json.dump(response.json(), f)
# Out:
# 200
#
# Получен результат
# {'base': 'stations',
#  'clouds': {'all': 75},
#  'cod': 200,
#  'coord': {'lat': 55, 'lon': 73.4},
#  'dt': 1672671714,
#  'id': 1496153,
#  'main': {'feels_like': -20.06,
#           'humidity': 85,
#           'pressure': 1019,
#           'temp': -13.06,
#           'temp_max': -13.06,
#           'temp_min': -13.06},
#  'name': 'Омск',
#  'sys': {'country': 'RU',
#          'id': 8960,
#          'sunrise': 1672630267,
#          'sunset': 1672656531,
#          'type': 1},
#  'timezone': 21600,
#  'visibility': 10000,
#  'weather': [{'description': 'облачно с прояснениями',
#               'icon': '04n',
#               'id': 803,
#               'main': 'Clouds'}],
#  'wind': {'deg': 140, 'speed': 6}}
