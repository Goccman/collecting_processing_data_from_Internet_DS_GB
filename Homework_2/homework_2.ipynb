# %%
from pprint import pprint
from lxml import html
import requests

# %%
USER_AGENT = 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/104.0.0.0 Safari/537.36'
URL = 'https://lenta.ru/'

# %%
headers = {
    'User-Agent': USER_AGENT,
}

params = {
    'sso_failed': '',
}

# %%
def get_content_dom_from_html_text(url, headers=None, params=None):
    response = requests.get(url, headers=headers, params=params)
    content_dom = html.fromstring(response.text)

    print(response.url)
    
    return content_dom


def parser_lenta_news(content_dom):
    news_container = content_dom.xpath("//a[contains(@class, 'card-')]")
    lenta_news = []
    for new_container in news_container:
        new_source = new_container.xpath(".//*[name()='svg']/*[name()='use']/attribute::*")
        if len(new_source) == 1:
            new_source = new_source[0].split('ui-label_')
            if len(new_source) == 2:
                new_source = new_source[1]
            else:
                new_source = 'Lenta.ru'
        else:
            new_source = 'Lenta.ru' 
        new_text = new_container.xpath(".//span[contains(@class, 'card-')]/text()")
        if len(new_text) == 1:
            new_text = new_text[0]
        else:
            new_text = None  
        new_link = URL + new_container.xpath("./@href")[0]
        
        new_date = new_container.xpath(".//time/text()")
        if len(new_date) == 1:
            new_date = new_date[0]
        else:
            new_date = None
        news_dict = {
            'new_source': new_source,
            'new_text': new_text,
            'new_link': new_link,
            'new_date': new_date,
        }
        lenta_news.append(news_dict)
        
    return lenta_news

# %%
dom = get_content_dom_from_html_text(URL, headers=headers, params=params)
# Out:
# https://lenta.ru/?sso_failed=

# %%
lenta_news = parser_lenta_news(dom)
lenta_news
# Out:
# [{'new_source': 'Lenta.ru',
#   'new_text': None,
#   'new_link': 'https://lenta.ru//news/2023/01/05/ogon/',
#   'new_date': '18:12'},
#  {'new_source': 'Lenta.ru',
#   'new_text': 'Грузинский боец UFC подрался в испанском баре',
#   'new_link': 'https://lenta.ru//news/2023/01/05/barilya/',
#   'new_date': '18:28'},
#  {'new_source': 'Lenta.ru',
#   'new_text': 'В Индии задержали туриста из России',
#   'new_link': 'https://lenta.ru//news/2023/01/05/turisto/',
#   'new_date': '18:26'},
#  {'new_source': 'Lenta.ru',
#   'new_text': 'Пропала 69-летняя звезда «Сватов»',
#   'new_link': 'https://lenta.ru//news/2023/01/05/kravchenko/',
#   'new_date': '18:23'},
#  {'new_source': 'Lenta.ru',
#   'new_text': 'Помощник Рейгана назвал смехотворными заявления о скором захвате Крыма Киевом',
#   'new_link': 'https://lenta.ru//news/2023/01/05/krym_christmas/',
#   'new_date': '18:20'},
#  {'new_source': 'Lenta.ru',
#   'new_text': 'Никиту Михалкова экстренно госпитализировали в Москве',
#   'new_link': 'https://lenta.ru/https://moslenta.ru/news/lyudi/mikhalkov-05-01-2023.htm',
#   'new_date': '18:16'},
#  {'new_source': 'Lenta.ru',
#   'new_text': 'Германия передала Украине шерстяные одеяла и дроны',
#   'new_link': 'https://lenta.ru//news/2023/01/05/peredala/',
#   'new_date': '18:05'},
#  {'new_source': 'Lenta.ru',
#   'new_text': 'Необычный способ выгула собаки москвичом рассмешил пользователей сети',
#   'new_link': 'https://lenta.ru/https://moslenta.ru/news/city/sposob-vygula-sobaki-05-01-2023.htm/',
#   'new_date': '18:02'},
#  {'new_source': 'Lenta.ru',
#   'new_text': 'Аномально теплая погода спасла Европу от энергокризиса',
#   'new_link': 'https://lenta.ru//news/2023/01/05/energo/',
#   'new_date': '17:55'},
#  {'new_source': 'Lenta.ru',
#   'new_text': 'Американский офицер оценил российское оружие',
#   'new_link': 'https://lenta.ru//news/2023/01/05/ohotnic/',
#   'new_date': '17:41'},
#  {'new_source': 'Lenta.ru',
#   'new_text': 'Кадыров вернул украинской военной привезенного из Мариуполя в Чечню пса',
#   'new_link': 'https://lenta.ru//news/2023/01/05/doggo/',
#   'new_date': '17:40'},
#  {'new_source': 'Lenta.ru',
#   'new_text': 'Минфин заявил о падении цены за баррель Urals ниже нефтяного потолка',
#   'new_link': 'https://lenta.ru//news/2023/01/05/urals/',
#   'new_date': '17:36'},
#  {'new_source': 'Lenta.ru',
#   'new_text': 'ФСБ сорвала теракт на железной дороге в Челябинской области',
#   'new_link': 'https://lenta.ru//news/2023/01/05/saboteurs/',
#   'new_date': '17:09'},
#  {'new_source': 'Lenta.ru',
#   'new_text': ' Соцсети все больше влияют на мировую политику. Какие угрозы это несет?',
#   'new_link': 'https://lenta.ru//articles/2023/01/05/twiplomacy/',
#   'new_date': '00:01'},
#  {'new_source': 'Lenta.ru',
#   'new_text': ' Сотни тысяч зэков отправили на Великую Отечественную. Как это изменило преступный мир?',
#   'new_link': 'https://lenta.ru//articles/2023/01/05/thiefs/',
#   'new_date': '00:01'},
#  {'new_source': 'Lenta.ru',
#   'new_text': 'Никита Михалков попал в больницу с пневмонией',
#   'new_link': 'https://lenta.ru//news/2023/01/05/mihal/',
#   'new_date': '17:36'},
#  {'new_source': 'Lenta.ru',
#   'new_text': 'Украина потеряла почти всю ветровую генерацию электроэнергии',
#   'new_link': 'https://lenta.ru//news/2023/01/05/generacia/',
#   'new_date': '17:27'},
#  {'new_source': 'Lenta.ru',
#   'new_text': 'Путин позвонил семилетнему россиянину',
#   'new_link': 'https://lenta.ru//news/2023/01/05/semmm/',
#   'new_date': '17:22'},
#  {'new_source': 'Lenta.ru',
#   'new_text': 'Оставшийся один дома 10-летний россиянин выпрыгнул из окна и спасся от пожара',
#   'new_link': 'https://lenta.ru//news/2023/01/05/fireescapes/',
#   'new_date': '17:20'},
#  {'new_source': 'Lenta.ru',
#   'new_text': 'Доктор Абакумов дал рекомендации по правильному выходу из похмелья',
#   'new_link': 'https://lenta.ru/https://moslenta.ru/news/lyudi/doktor-abakumov-05-01-2023.htm',
#   'new_date': '17:18'},
#  {'new_source': 'Lenta.ru',
#   'new_text': 'Число пострадавших при пожаре в Чебоксарах возросло',
#   'new_link': 'https://lenta.ru//news/2023/01/05/cheby2/',
#   'new_date': '17:12'},
#  {'new_source': 'Lenta.ru',
#   'new_text': ' Почему жители мексиканского города уверены, что находятся под покровительством инопланетян',
#   'new_link': 'https://lenta.ru//articles/2023/01/05/amupac/',
#   'new_date': '00:01'},
#  {'new_source': 'Lenta.ru',
#   'new_text': 'Посольство США обратилось к россиянам',
#   'new_link': 'https://lenta.ru//news/2023/01/05/obrashenie/',
#   'new_date': None},
#  {'new_source': 'Lenta.ru',
#   'new_text': 'Патриарх Кирилл призвал к рождественскому перемирию на Украине',
#   'new_link': 'https://lenta.ru//news/2023/01/05/peremir/',
#   'new_date': None},
#  {'new_source': 'Lenta.ru',
#   'new_text': 'Пригожин сообщил о завершении контракта и помиловании первой группы заключенных',
#   'new_link': 'https://lenta.ru//news/2023/01/05/pomil/',
#   'new_date': None},
#  {'new_source': 'Lenta.ru',
#   'new_text': 'Пушилин сообщил о переводе почти всех раненных в Макеевке в другие регионы',
#   'new_link': 'https://lenta.ru//news/2023/01/05/regiony/',
#   'new_date': None},
#  {'new_source': 'Lenta.ru',
#   'new_text': 'Опубликованы переговоры польских наемников в зоне спецоперации',
#   'new_link': 'https://lenta.ru//news/2023/01/05/ddnnrr/',
#   'new_date': None},
#  {'new_source': 'Lenta.ru',
#   'new_text': 'Путин отдал приказ отправить на боевую службу «Адмирала Горшкова»',
#   'new_link': 'https://lenta.ru//news/2023/01/04/putinadmiral/',
#   'new_date': None},
#  {'new_source': 'Lenta.ru',
#   'new_text': 'Кадыров озвучил число возвращенных с Украины российских военнопленных за декабрь',
#   'new_link': 'https://lenta.ru//news/2023/01/04/200_plen/',
#   'new_date': None},
#  {'new_source': 'Lenta.ru',
#   'new_text': 'Число погибших военных после удара ВСУ по Макеевке увеличилось до 89 человек',
#   'new_link': 'https://lenta.ru//news/2023/01/04/makeevka_minoborony/',
#   'new_date': None},
#  {'new_source': 'Lenta.ru',
#   'new_text': 'Умер последний председатель Верховного совета РСФСР Хасбулатов',
#   'new_link': 'https://lenta.ru//news/2023/01/03/khasbulatov/',
#   'new_date': None},
#  {'new_source': 'Lenta.ru',
#   'new_text': 'Путин утвердил приказ о зачете одного дня службы в зоне СВО за два',
#   'new_link': 'https://lenta.ru//news/2023/01/03/zachet/',
#   'new_date': None},
#  {'new_source': 'Lenta.ru',
#   'new_text': ' Пенсии, выплаты, стоимость водки, ЖКХ и техосмотра: главные перемены в 2023 году',
#   'new_link': 'https://lenta.ru//articles/2022/12/29/changes/',
#   'new_date': '00:02, 29 декабря 2022'},
#  {'new_source': 'Lenta.ru',
#   'new_text': ' Почему это вошло в норму и как заставить их повзрослеть?',
#   'new_link': 'https://lenta.ru//articles/2022/12/28/latekids/',
#   'new_date': '00:02, 28 декабря 2022'},
#  {'new_source': 'Lenta.ru',
#   'new_text': ' Как легендарный советский разведчик боролся с подпольем в послевоенной Украине',
#   'new_link': 'https://lenta.ru//articles/2022/12/29/razvedka/',
#   'new_date': '00:02, 29 декабря 2022'},
#  {'new_source': 'Lenta.ru',
#   'new_text': ' Самые известные люди, скончавшиеся в 2022 году',
#   'new_link': 'https://lenta.ru//articles/2022/12/31/gone2022/',
#   'new_date': '00:17, 31 декабря 2022'},
#  {'new_source': 'Lenta.ru',
#   'new_text': ' Как 17-летняя дочь медсестры роскошно выходила замуж за султана Брунея',
#   'new_link': 'https://lenta.ru//articles/2023/01/01/sarah_salleh/',
#   'new_date': '00:01, 1 января 2023'},
#  {'new_source': 'Lenta.ru',
#   'new_text': ' Как молодежь подсела на таблетки террористов и почему на помощь зовут Россию?',
#   'new_link': 'https://lenta.ru//articles/2022/12/28/narkotik_jihada/',
#   'new_date': '00:01, 28 декабря 2022'},
#  {'new_source': 'Lenta.ru',
#   'new_text': ' 60 лет назад появился «Голубой огонек». Как он стал культовым и за что его обожали миллионы',
#   'new_link': 'https://lenta.ru//articles/2022/12/31/blue_light/',
#   'new_date': '00:17, 31 декабря 2022'},
#  {'new_source': 'Lenta.ru',
#   'new_text': ' Умер легендарный Пеле. Каким запомнят Короля футбола болельщики всего мира?',
#   'new_link': 'https://lenta.ru//articles/2022/12/29/pelekorol/',
#   'new_date': '22:39, 29 декабря 2022'},
#  {'new_source': 'Lenta.ru',
#   'new_text': ' Россия хочет уйти из УЕФА и играть в Азии. Почему это решение обернется катастрофой?',
#   'new_link': 'https://lenta.ru//articles/2022/12/29/asia/',
#   'new_date': '00:02, 29 декабря 2022'},
#  {'new_source': 'Lenta.ru',
#   'new_text': ' умерла панк-икона Вивьен Вествуд',
#   'new_link': 'https://lenta.ru//articles/2022/12/30/vivienne/',
#   'new_date': '02:36, 30 декабря 2022'},
#  {'new_source': 'Lenta.ru',
#   'new_text': ' Как за 2022 год изменилась мировая медицина?',
#   'new_link': 'https://lenta.ru//articles/2023/01/05/topfivemedical/',
#   'new_date': '00:01'},
#  {'new_source': 'Lenta.ru',
#   'new_text': 'Украину не пригласили на саммит G20 в Индии',
#   'new_link': 'https://lenta.ru//news/2023/01/05/g20_dely/',
#   'new_date': '17:08'},
#  {'new_source': 'Lenta.ru',
#   'new_text': '34-летняя Кристина Асмус продемонстрировала фигуру в купальнике',
#   'new_link': 'https://lenta.ru/https://moslenta.ru/news/lyudi/kristina-asmus-05-01-2023.htm',
#   'new_date': '16:56'},
#  {'new_source': 'Lenta.ru',
#   'new_text': 'Главный храм Киево-Печерской лавры передали государству',
#   'new_link': 'https://lenta.ru//news/2023/01/05/uspen/',
#   'new_date': '16:55'},
#  {'new_source': 'Lenta.ru',
#   'new_text': 'Названы пять миллиардеров с самыми большими потерями за 2022 год',
#   'new_link': 'https://lenta.ru//news/2023/01/05/mllrd/',
#   'new_date': '16:50'},
#  {'new_source': 'Lenta.ru',
#   'new_text': 'В Крыму ответили на требование Киева вернуть «украденные квартиры»',
#   'new_link': 'https://lenta.ru//news/2023/01/05/krym_podolyak/',
#   'new_date': '16:45'},
#  {'new_source': 'Lenta.ru',
#   'new_text': 'В Италии опровергли сообщения о поставках Украине противопехотных мин',
#   'new_link': 'https://lenta.ru//news/2023/01/05/mins/',
#   'new_date': '16:36'},
#  {'new_source': 'Lenta.ru',
#   'new_text': ' «Стражи Галактики», «Дюна-2», ядерная бомба Нолана и 80-летний Индиана Джонс',
#   'new_link': 'https://lenta.ru//articles/2023/01/04/movies2023/',
#   'new_date': None},
#  {'new_source': 'Lenta.ru',
#   'new_text': 'В Белоруссии сообщили о наращивании совместной с Россией группировки войск',
#   'new_link': 'https://lenta.ru//news/2023/01/05/naraashibani/',
#   'new_date': '16:19'},
#  {'new_source': 'Lenta.ru',
#   'new_text': ' Что происходило в окрестностях Херсона накануне отвода российских войск',
#   'new_link': 'https://lenta.ru//articles/2022/11/10/kherson/',
#   'new_date': '00:01, 10 ноября 2022'},
#  {'new_source': 'Lenta.ru',
#   'new_text': 'Шестеро детей пострадали при пожаре в российском городе',
#   'new_link': 'https://lenta.ru//news/2023/01/05/cheby/',
#   'new_date': '16:10'},
#  {'new_source': 'Lenta.ru',
#   'new_text': 'Названы самые популярные у россиян новогодние направления за границей',
#   'new_link': 'https://lenta.ru/https://moslenta.ru/news/city/populyarnye-novogodnie-napravleniya-05-01-2023.htm/',
#   'new_date': '16:04'},
#  {'new_source': 'Lenta.ru',
#   'new_text': 'ВС России нанесли удар по позициям ВСУ под Сватово',
#   'new_link': 'https://lenta.ru//news/2023/01/05/svatovo/',
#   'new_date': '16:04'},
#  {'new_source': 'Lenta.ru',
#   'new_text': ' От каких болезней страдают современные мужчины и как их избежать?',
#   'new_link': 'https://lenta.ru//articles/2022/11/19/mens_day/',
#   'new_date': '00:02, 19 ноября 2022'},
#  {'new_source': 'Lenta.ru',
#   'new_text': 'В США заявили о разрушении Путиным планов Запада',
#   'new_link': 'https://lenta.ru//news/2023/01/05/westplans/',
#   'new_date': '15:59'},
#  {'new_source': 'Lenta.ru',
#   'new_text': 'Генсек НАТО назвал оружие путем к миру на Украине',
#   'new_link': 'https://lenta.ru//news/2023/01/05/oruzh/',
#   'new_date': '15:57'},
#  {'new_source': 'Lenta.ru',
#   'new_text': ' Как матери до сих пор ищут сыновей, пропавших во время войны в Чечне',
#   'new_link': 'https://lenta.ru//articles/2022/07/19/checnyapoisk/',
#   'new_date': '00:02, 19 июля 2022'},
#  {'new_source': 'Lenta.ru',
#   'new_text': 'Итальянская компания перестала закупать российский газ',
#   'new_link': 'https://lenta.ru//news/2023/01/05/perestali/',
#   'new_date': '15:51'},
#  {'new_source': 'Lenta.ru',
#   'new_text': 'Медведев рассказал о главном новогоднем подарке для НАТО',
#   'new_link': 'https://lenta.ru//news/2023/01/05/podarunok/',
#   'new_date': '15:38'},
#  {'new_source': 'Lenta.ru',
#   'new_text': 'Макгрегор восхитился тренировкой Федора Емельяненко',
#   'new_link': 'https://lenta.ru//news/2023/01/05/conormma/',
#   'new_date': '15:33'},
#  {'new_source': 'Lenta.ru',
#   'new_text': 'Завороженный падающим снегом медведь Диксон попал на видео',
#   'new_link': 'https://lenta.ru/https://moslenta.ru/news/city/dikson-05-01-2023.htm',
#   'new_date': '15:30'},
#  {'new_source': 'Lenta.ru',
#   'new_text': 'Названы обстоятельства для ослабления рубля',
#   'new_link': 'https://lenta.ru//news/2023/01/05/slabrub/',
#   'new_date': '15:30'},
#  {'new_source': 'Lenta.ru',
#   'new_text': ' Российская разведчица-нелегал 20 лет добывала тайны США. Как ей удавалось обманывать спецслужбы?',
#   'new_link': 'https://lenta.ru//articles/2022/06/28/razvedka/',
#   'new_date': '00:01, 28 июня 2022'},
#  {'new_source': 'Lenta.ru',
#   'new_text': 'Эрдоган допустил встречу с президентом Сирии',
#   'new_link': 'https://lenta.ru//news/2023/01/05/er_asad/',
#   'new_date': '15:30'},
#  {'new_source': 'moslenta',
#   'new_text': ' Как живет и работает настоящая московская Снегурочка',
#   'new_link': 'https://lenta.ru/https://lenta.ru/extlink/2022/12/21/snegurochk_iz_moskvy/',
#   'new_date': '00:09'},
#  {'new_source': 'moslenta',
#   'new_text': ' Как москвичи нашли квартиру с отдельным выходом прямо в лес',
#   'new_link': 'https://lenta.ru/https://lenta.ru/extlink/2022/12/23/kvartira_s_vyhodom_v_les/',
#   'new_date': '00:05, 4 января 2023'},
#  {'new_source': 'secretmag',
#   'new_text': ' Главные происшествия уходящего года по версии «Секрета»',
#   'new_link': 'https://lenta.ru/https://lenta.ru/extlink/2022/12/30/tragedii/',
#   'new_date': '08:01, 3 января 2023'},
#  {'new_source': 'moslenta',
#   'new_text': ' Как встретить Новый год по-татарски',
#   'new_link': 'https://lenta.ru/https://lenta.ru/extlink/2022/12/26/tatarskiy_novyi_god/',
#   'new_date': '00:05, 3 января 2023'},
#  {'new_source': 'secretmag',
#   'new_text': ' Хроники взлёта и падения рубля в 2022 году',
#   'new_link': 'https://lenta.ru/https://lenta.ru/extlink/2022/12/30/russkie-gorki/',
#   'new_date': '08:00, 2 января 2023'},
#  {'new_source': 'secretmag',
#   'new_text': ' Перепись неудачников 2022 года',
#   'new_link': 'https://lenta.ru/https://lenta.ru/extlink/2022/12/30/zhertvy/',
#   'new_date': '08:00, 2 января 2023'},
#  {'new_source': 'moslenta',
#   'new_text': ' Зачем москвичам ехать на выходные в Ярославль',
#   'new_link': 'https://lenta.ru/https://lenta.ru/extlink/2022/12/26/poehali_v_yaroslavl/',
#   'new_date': '00:05, 2 января 2023'},
#  {'new_source': 'secretmag',
#   'new_text': ' Предсказания Жириновского, Ванги и Нострадамуса на 2023 год',
#   'new_link': 'https://lenta.ru/https://lenta.ru/extlink/2022/12/30/predskazaniya/',
#   'new_date': '08:02, 1 января 2023'},
#  {'new_source': 'secretmag',
#   'new_text': ' Как коронавирус перенёс 2022 год',
#   'new_link': 'https://lenta.ru/https://lenta.ru/extlink/2022/12/28/koronavirus/',
#   'new_date': '08:02, 1 января 2023'},
#  {'new_source': 'moslenta',
#   'new_text': ' Что ждет москвичей в новом 2023 году',
#   'new_link': 'https://lenta.ru/https://lenta.ru/extlink/2022/12/17/chto_izmenitsya_s_yanvarya_2023/',
#   'new_date': '00:05, 1 января 2023'},
#  {'new_source': 'moslenta',
#   'new_text': ' Как Дед Мороз и Снегурочка пошли в народ',
#   'new_link': 'https://lenta.ru/https://lenta.ru/extlink/2022/12/20/ded_moroz_na_dom/',
#   'new_date': '00:05, 31 декабря 2022'},
#  {'new_source': 'motor',
#   'new_text': ' Выбираем главные машины и главных людей автопрома большой и великой страны',
#   'new_link': 'https://lenta.ru/https://lenta.ru/extlink/2022/12/30/best-soviet-cars/',
#   'new_date': '09:33, 30 декабря 2022'},
#  {'new_source': 'secretmag',
#   'new_text': ' Прогнозы на 2022 год, которые с треском провалились',
#   'new_link': 'https://lenta.ru/https://lenta.ru/extlink/2022/12/28/prognozy/',
#   'new_date': '08:15, 30 декабря 2022'},
#  {'new_source': 'secretmag',
#   'new_text': ' 2022 год круто изменил жизни россиян — вот что они про это говорят',
#   'new_link': 'https://lenta.ru/https://lenta.ru/extlink/2022/12/28/vsyo-namnogo-slozhnee/',
#   'new_date': '08:15, 30 декабря 2022'},
#  {'new_source': 'moslenta',
#   'new_text': ' Как не набрать лишнего и не отравиться за новогодним столом',
#   'new_link': 'https://lenta.ru/https://lenta.ru/extlink/2022/12/16/dietolog_pro_novogodnyi_stol/',
#   'new_date': '00:05, 30 декабря 2022'},
#  {'new_source': 'motor',
#   'new_text': ' Очень мощные бензоэлектрические машины',
#   'new_link': 'https://lenta.ru/https://lenta.ru/extlink/2022/12/29/madhybrids/',
#   'new_date': '09:43, 29 декабря 2022'},
#  {'new_source': 'secretmag',
#   'new_text': ' Почему российские убийцы Instagram* и YouTube никого не убили',
#   'new_link': 'https://lenta.ru/https://lenta.ru/extlink/2022/12/28/ne-ubili/',
#   'new_date': '08:02, 29 декабря 2022'},
#  {'new_source': 'secretmag',
#   'new_text': ' Исследование «Секрета» об аварийках',
#   'new_link': 'https://lenta.ru/https://lenta.ru/extlink/2022/12/28/avariiki/',
#   'new_date': '08:02, 29 декабря 2022'},
#  {'new_source': 'secretmag',
#   'new_text': ' Куда инвестировать россиянину в 2023 году',
#   'new_link': 'https://lenta.ru/https://lenta.ru/extlink/2022/12/28/kuda-investirovat/',
#   'new_date': '08:02, 29 декабря 2022'},
#  {'new_source': 'moslenta',
#   'new_text': ' Психолог о праздновании Нового года с детьми и печальной правде о Деде Морозе',
#   'new_link': 'https://lenta.ru/https://lenta.ru/extlink/2022/12/16/psiholog_pro_detey_i_novyi_god/',
#   'new_date': '00:06, 29 декабря 2022'},
#  {'new_source': 'Lenta.ru',
#   'new_text': 'СБУ подтвердила задержание замглавы Одесской областной администрации',
#   'new_link': 'https://lenta.ru//news/2023/01/05/sbupodtv/',
#   'new_date': '15:22'},
#  {'new_source': 'Lenta.ru',
#   'new_text': 'Эрдоган заявил о планах обеспечить российским зерном бедные страны Африки',
#   'new_link': 'https://lenta.ru//news/2023/01/05/zerno/',
#   'new_date': '15:20'},
#  {'new_source': 'Lenta.ru',
#   'new_text': ' 25 главных сериалов января',
#   'new_link': 'https://lenta.ru//articles/2023/01/02/seriesjanuary/',
#   'new_date': '00:01, 2 января 2023'},
#  {'new_source': 'Lenta.ru',
#   'new_text': 'Медведев оценил обращение США к россиянам словами «предел моральной деградации»',
#   'new_link': 'https://lenta.ru//news/2023/01/05/ocenil/',
#   'new_date': '15:16'},
#  {'new_source': 'Lenta.ru',
#   'new_text': ' Сельский быт и обнаженка — что нашла фотограф в русской деревне',
#   'new_link': 'https://lenta.ru//articles/2022/04/28/spas/',
#   'new_date': None},
#  {'new_source': 'Lenta.ru',
#   'new_text': 'Опубликована карта боевых действий на Украине на 5 января',
#   'new_link': 'https://lenta.ru//news/2023/01/05/mo_5jan/',
#   'new_date': '15:13'},
#  {'new_source': 'Lenta.ru',
#   'new_text': 'Норвегия передала Украине 10 тысяч артиллерийских снарядов',
#   'new_link': 'https://lenta.ru//news/2023/01/05/pomosh/',
#   'new_date': '15:05'},
#  {'new_source': 'Lenta.ru',
#   'new_text': 'Стала известна причина отказа США поставлять Украине танки Abrams',
#   'new_link': 'https://lenta.ru//news/2023/01/05/abramsi/',
#   'new_date': '15:01'},
#  {'new_source': 'Lenta.ru',
#   'new_text': 'Эрдоган анонсировал разговор с Зеленским',
#   'new_link': 'https://lenta.ru//news/2023/01/05/rozmova/',
#   'new_date': '14:57'},
#  {'new_source': 'Lenta.ru',
#   'new_text': 'Россиянам перечислили правила безопасности при использовании бани',
#   'new_link': 'https://lenta.ru/https://moslenta.ru/news/lyudi/ispolzovanii-bani-05-01-2023.htm',
#   'new_date': '14:53'},
#  {'new_source': 'Lenta.ru',
#   'new_text': ' Способ отвлечься и восстановить силы: почему праздники важны даже в самое тяжелое время?',
#   'new_link': 'https://lenta.ru//articles/2023/01/04/prazdniki/',
#   'new_date': '00:03, 4 января 2023'},
#  {'new_source': 'Lenta.ru',
#   'new_text': 'На Украине снесли памятник писателю Николаю Островскому',
#   'new_link': 'https://lenta.ru//news/2023/01/05/ostrov/',
#   'new_date': '14:51'},
#  {'new_source': 'Lenta.ru',
#   'new_text': ' Когда ехать в самые красивые места России: календарь на год',
#   'new_link': 'https://lenta.ru//articles/2023/01/04/season/',
#   'new_date': None},
#  {'new_source': 'Lenta.ru',
#   'new_text': 'Российского тренера обвинили в жестоком обращении с гимнастками в Италии',
#   'new_link': 'https://lenta.ru//news/2023/01/05/italyviolence/',
#   'new_date': '14:49'},
#  {'new_source': 'Lenta.ru',
#   'new_text': 'Путин заявил Эрдогану о готовности России к серьезному диалогу по Украине',
#   'new_link': 'https://lenta.ru//news/2023/01/05/gotovnost/',
#   'new_date': '14:44'},
#  {'new_source': 'Lenta.ru',
#   'new_text': 'Принц Гарри отказался приезжать на коронацию отца',
#   'new_link': 'https://lenta.ru//news/2023/01/05/harry_no/',
#   'new_date': '14:42'},
#  {'new_source': 'Lenta.ru',
#   'new_text': 'Перечислены четыре способа предотвратить старение кожи',
#   'new_link': 'https://lenta.ru//news/2023/01/05/youngface/',
#   'new_date': '14:36'},
#  {'new_source': 'Lenta.ru',
#   'new_text': 'Пьяная россиянка попыталась проломить голову фельдшера скорой помощи о стену',
#   'new_link': 'https://lenta.ru//news/2023/01/05/pacientka/',
#   'new_date': '14:30'},
#  {'new_source': 'Lenta.ru',
#   'new_text': 'Лев атаковал дрессировщика во время выступления на арене цирка в Сочи',
#   'new_link': 'https://lenta.ru//news/2023/01/05/lev/',
#   'new_date': '14:28'},
#  {'new_source': 'Lenta.ru',
#   'new_text': ' Она устраивает пытки и убивает на улицах, а теперь угрожает принцессе Голландии',
#   'new_link': 'https://lenta.ru//articles/2022/10/20/mocro/',
#   'new_date': '00:01, 20 октября 2022'},
#  {'new_source': 'Lenta.ru',
#   'new_text': 'Минобороны сообщило об уничтожении членов батальона имени Шейха Мансура',
#   'new_link': 'https://lenta.ru//news/2023/01/05/batalyon/',
#   'new_date': '14:26'},
#  {'new_source': 'Lenta.ru',
#   'new_text': ' В Азербайджане живут русские христиане-отступники. Как они стали друзьями президента страны?',
#   'new_link': 'https://lenta.ru//articles/2023/01/03/molokane_az/',
#   'new_date': '00:01, 3 января 2023'},
#  {'new_source': 'Lenta.ru',
#   'new_text': 'ВС РФ заявили об уничтожении западного вооружения в ЛНР и на Украине',
#   'new_link': 'https://lenta.ru//news/2023/01/05/otchitalis/',
#   'new_date': '14:23'},
#  {'new_source': 'Lenta.ru',
#   'new_text': 'В ДНР сбили два украинских самолета',
#   'new_link': 'https://lenta.ru//news/2023/01/05/samoleti/',
#   'new_date': '14:09'},
#  {'new_source': 'Lenta.ru',
#   'new_text': 'В ДНР уничтожили украинские самоходные гаубицы и РСЗО',
#   'new_link': 'https://lenta.ru//news/2023/01/05/rszo/',
#   'new_date': '14:07'},
#  {'new_source': 'Lenta.ru',
#   'new_text': ' Россиянка устроилась на королевскую яхту. Как она получила работу мечты?',
#   'new_link': 'https://lenta.ru//articles/2022/02/03/yacht/',
#   'new_date': '00:02, 3 февраля 2022'},
#  {'new_source': 'Lenta.ru',
#   'new_text': 'Минобороны сообщило о перехвате снарядов HIMARS',
#   'new_link': 'https://lenta.ru//news/2023/01/05/minno/',
#   'new_date': '14:07'},
#  {'new_source': 'Lenta.ru',
#   'new_text': 'Российская артиллерия нанесла удар по десантникам ВСУ под Донецком',
#   'new_link': 'https://lenta.ru//news/2023/01/05/mo_art/',
#   'new_date': '14:03'},
#  {'new_source': 'Lenta.ru',
#   'new_text': ' самые резонансные судебные процессы 2023 года',
#   'new_link': 'https://lenta.ru//articles/2023/01/04/prigovor/',
#   'new_date': None},
#  {'new_source': 'Lenta.ru',
#   'new_text': 'Aston Martin выпустит финальный DBS с 770-сильным V12',
#   'new_link': 'https://lenta.ru/https://motor.ru/news/dbs-770-ultimate-05-01-2023.htm',
#   'new_date': '14:30'},
#  {'new_source': 'Lenta.ru',
#   'new_text': 'Минобороны сообщило о потерях ВСУ на купянском направлении',
#   'new_link': 'https://lenta.ru//news/2023/01/05/minkup/',
#   'new_date': '14:02'},
#  {'new_source': 'Lenta.ru',
#   'new_text': 'Путин и Эрдоган обсудили ситуацию на Украине и в Сирии',
#   'new_link': 'https://lenta.ru//news/2023/01/05/pu_er/',
#   'new_date': '13:57'},
#  {'new_source': 'Lenta.ru',
#   'new_text': 'Минобороны заявило об уничтожении военных ВСУ на южно-донецком направлении',
#   'new_link': 'https://lenta.ru//news/2023/01/05/sorok/',
#   'new_date': '13:57'},
#  {'new_source': 'Lenta.ru',
#   'new_text': 'Кремль высказался о планах Путина на Рождество',
#   'new_link': 'https://lenta.ru//news/2023/01/05/rozhd/',
#   'new_date': '13:54'},
#  {'new_source': 'Lenta.ru',
#   'new_text': ' Как сборная Чехословакии по хоккею мстила СССР за подавление Пражской весны',
#   'new_link': 'https://lenta.ru//articles/2023/01/03/ussr_chekh/',
#   'new_date': '00:01, 3 января 2023'},
#  {'new_source': 'Lenta.ru',
#   'new_text': 'Французский политик назвал безумием передачу бронемашин AMX-10RC Украине',
#   'new_link': 'https://lenta.ru//news/2023/01/05/filippo/',
#   'new_date': '13:44'},
#  {'new_source': 'Lenta.ru',
#   'new_text': 'Бывший игрок МЮ рассказал о «купившей все матчи» на ЧМ-2018 сборной России',
#   'new_link': 'https://lenta.ru//news/2023/01/05/kanchelskis/',
#   'new_date': '13:42'},
#  {'new_source': 'Lenta.ru',
#   'new_text': 'На Украине увидели бойцов спецподразделений Запада',
#   'new_link': 'https://lenta.ru//news/2023/01/05/speccc/',
#   'new_date': '13:23'},
#  {'new_source': 'Lenta.ru',
#   'new_text': ' Как в популярном детском шоу из 1990-х углядели пропаганду суицида?',
#   'new_link': 'https://lenta.ru//articles/2023/01/03/vkysnye_istorrii/',
#   'new_date': '00:01, 3 января 2023'},
#  {'new_source': 'Lenta.ru',
#   'new_text': 'В Белоруссии начался суд над Нобелевским лауреатом',
#   'new_link': 'https://lenta.ru//news/2023/01/05/laureat/',
#   'new_date': '13:38'},
#  {'new_source': 'Lenta.ru',
#   'new_text': ' Кто, как и зачем пьет алкоголь с половыми органами, фекалиями и мочой диабетиков?',
#   'new_link': 'https://lenta.ru//articles/2023/01/03/alcohol/',
#   'new_date': '00:02, 3 января 2023'},
#  {'new_source': 'Lenta.ru',
#   'new_text': 'Стали известны первые слова короля Британии после рождения принца Гарри',
#   'new_link': 'https://lenta.ru//news/2023/01/05/harryandkarl/',
#   'new_date': '13:29'},
#  {'new_source': 'Lenta.ru',
#   'new_text': 'Волочкова поделилась видео топлес с отдыха',
#   'new_link': 'https://lenta.ru/https://moslenta.ru/news/lyudi/video-toples-05-01-2023.htm',
#   'new_date': '13:25'},
#  {'new_source': 'Lenta.ru',
#   'new_text': 'Названы меры поддержки Россией новых регионов в 2022 году',
#   'new_link': 'https://lenta.ru//news/2023/01/05/mery/',
#   'new_date': '13:24'},
#  {'new_source': 'Lenta.ru',
#   'new_text': 'Экс-полковник британской армии допустил начало войны России и НАТО в 2023 году',
#   'new_link': 'https://lenta.ru//news/2023/01/05/russia_nato/',
#   'new_date': '13:21'},
#  {'new_source': 'Lenta.ru',
#   'new_text': 'Смертельное ДТП с маршруткой и легковушкой на российской трассе попало на видео',
#   'new_link': 'https://lenta.ru//news/2023/01/05/dtp/',
#   'new_date': '13:17'},
#  {'new_source': 'Lenta.ru',
#   'new_text': ' главные новогодние ЧП в России',
#   'new_link': 'https://lenta.ru//articles/2023/01/02/newyear/',
#   'new_date': '12:56, 2 января 2023'},
#  {'new_source': 'Lenta.ru',
#   'new_text': 'Украине предрекли масштабное наступление зимой',
#   'new_link': 'https://lenta.ru//news/2023/01/05/nastupl/',
#   'new_date': '13:02'},
#  {'new_source': 'Lenta.ru',
#   'new_text': ' 40 лет назад в СССР наступил год самого загадочного генсека. Почему Андропов популярен до сих пор?',
#   'new_link': 'https://lenta.ru//articles/2023/01/02/andropov/',
#   'new_date': '00:01, 2 января 2023'},
#  {'new_source': 'Lenta.ru',
#   'new_text': 'Россиянки бросились рожать за границей',
#   'new_link': 'https://lenta.ru//news/2023/01/05/birth/',
#   'new_date': '12:58'},
#  {'new_source': 'Lenta.ru',
#   'new_text': 'В Румынии засняли поезд с турецкими бронеавтомобилями для Украины',
#   'new_link': 'https://lenta.ru//news/2023/01/05/kirpi/',
#   'new_date': '12:52'},
#  {'new_source': 'Lenta.ru',
#   'new_text': 'Названы самые популярные у россиян блюда на рождественском столе',
#   'new_link': 'https://lenta.ru/https://moslenta.ru/news/lyudi/blyuda-na-stole-05-01-2023.htm',
#   'new_date': '12:48'},
#  {'new_source': 'Lenta.ru',
#   'new_text': 'Россиянам напомнили о необходимости платить налог за подарки',
#   'new_link': 'https://lenta.ru//news/2023/01/05/podarki/',
#   'new_date': '12:30'},
#  {'new_source': 'Lenta.ru',
#   'new_text': 'Эрдоган обсудил с Путиным проект газового хаба',
#   'new_link': 'https://lenta.ru//news/2023/01/05/erdogan_putin/',
#   'new_date': '12:29'},
#  {'new_source': 'Lenta.ru',
#   'new_text': 'Эрдоган призвал к скорейшему мирному урегулированию украинского конфликта',
#   'new_link': 'https://lenta.ru//news/2023/01/05/erdogan/',
#   'new_date': '12:28'},
#  {'new_source': 'Lenta.ru',
#   'new_text': ' самые прорывные научные открытия 2022 года',
#   'new_link': 'https://lenta.ru//articles/2023/01/02/top_science/',
#   'new_date': '00:01, 2 января 2023'},
#  {'new_source': 'Lenta.ru',
#   'new_text': 'Итальянского легкоатлета дисквалифицировали на 36 лет',
#   'new_link': 'https://lenta.ru//news/2023/01/05/doping36/',
#   'new_date': '12:27'},
#  {'new_source': 'Lenta.ru',
#   'new_text': ' Почему их стоит увидеть?',
#   'new_link': 'https://lenta.ru//articles/2023/01/01/clipmakers/',
#   'new_date': '00:01, 1 января 2023'},
#  {'new_source': 'Lenta.ru',
#   'new_text': 'Психолог назвала способы легко войти в рабочий режим после праздников',
#   'new_link': 'https://lenta.ru/https://moslenta.ru/news/city/sposoby-legko-voiti-v-rabochii-rezhim-05-01-2023.htm',
#   'new_date': '12:21'},
#  {'new_source': 'Lenta.ru',
#   'new_text': 'В США увидели помощь Украине в выводе войск из Афганистана',
#   'new_link': 'https://lenta.ru//news/2023/01/05/helpafgan/',
#   'new_date': '12:17'}]
