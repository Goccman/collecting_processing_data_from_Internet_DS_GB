# %% [markdown]
# # **Парсинг данных. HTML, Beautiful Soap**
#
#  Парсинг с применением библиотеки Requests, и обработкой полученной структуры — с помощью библиотеки Beautiful Soup.
#  Парсинг вакансий на сайте hh.ru в регионе Екатеринбург по ключевому запросу "Python", с отображением информации о названии объявления, размера ЗП с отображением вилки от минимальной до максимальной, валютой ЗП, ссылкой на вакансию.

# %%
from pprint import pprint
from bs4 import BeautifulSoup as bs
import requests
from time import sleep

# %%
USER_AGENT = 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/104.0.0.0 Safari/537.36'

URL_FIRST_PAGE_HH = 'https://ekaterinburg.hh.ru/search/vacancy?text=Python&from=suggest_post&salary=&area=3&no_magic=true&ored_clusters=true&items_on_page=20&enable_snippets=true'

# %%
headers = {
    'User-Agent': USER_AGENT,
}

# %%
def parse_hh(url_page, headers, result=[], index_page=1):
    response = requests.get(url_page, headers=headers)
    if response.status_code != 200:
      print('Парсинг завершен')
      return result
    else:
      print('Cтраница №%d, ссылка: %s'%(index_page, response.url))

    dom = bs(response.content, 'html.parser')
    vacancies = dom.find_all('div', {'class': 'vacancy-serp-item__layout'})
    for vacancy in vacancies:
      result.append(parse_vacancy_hh(vacancy))

    link_next_page = dom.find('a', {'data-qa': 'pager-next'})
    if link_next_page:
      link_next_page =  'https://ekaterinburg.hh.ru' + link_next_page['href']
    else:
      print('Парсинг завершен')
      return result

    result = parse_hh(link_next_page, headers, result, index_page+1)   
    return result
     
def parse_vacancy_hh(dom_vacancy):
  sleep(0.1)
  vacancy_name = dom_vacancy.find('a').text

  vacancy_salary = dom_vacancy.find('span', {'class', 'bloko-header-section-3'})
  if vacancy_salary:
    vacancy_salary = vacancy_salary.text
    min_salary, max_salary, currency_salary = clean_salary(vacancy_salary)
  else:
    min_salary, max_salary, currency_salary = None, None, None

  vacancy_link = dom_vacancy.find('a')['href']
  
  return {
      'vacancy_name': vacancy_name,
      'vacancy_salary': vacancy_salary,
      'min_salary': min_salary,
      'max_salary': max_salary,
      'currency_salary': currency_salary,
      'vacancy_link': vacancy_link,
      'vacancy_source': 'hh.ru',
  }

def clean_salary(vacancy_salary_text, min_salary=None, max_salary=None, currency_salary=None):
  list_salary = vacancy_salary_text.replace('\u202f', '').split()
  for i in range(len(list_salary) - 1):
    if list_salary[i] == 'от':
      min_salary = int(list_salary[i + 1])
    elif list_salary[i] == 'до':
      max_salary = int(list_salary[i + 1])
    elif list_salary[i] == '–':
      min_salary = int(list_salary[i - 1])
      max_salary = int(list_salary[i + 1])
  currency_salary = list_salary[-1]

  return min_salary, max_salary, currency_salary

# %%
result = parse_hh(URL_FIRST_PAGE_HH, headers)
# Out:
# Cтраница №1, ссылка: https://ekaterinburg.hh.ru/search/vacancy?text=Python&from=suggest_post&salary=&area=3&no_magic=true&ored_clusters=true&items_on_page=20&enable_snippets=true
# Cтраница №2, ссылка: https://ekaterinburg.hh.ru/search/vacancy?text=Python&from=suggest_post&salary=&area=3&no_magic=true&ored_clusters=true&items_on_page=20&enable_snippets=true&page=1&hhtmFrom=vacancy_search_list
# Cтраница №3, ссылка: https://ekaterinburg.hh.ru/search/vacancy?text=Python&from=suggest_post&salary=&area=3&no_magic=true&ored_clusters=true&items_on_page=20&enable_snippets=true&page=2&hhtmFrom=vacancy_search_list
# Cтраница №4, ссылка: https://ekaterinburg.hh.ru/search/vacancy?text=Python&from=suggest_post&salary=&area=3&no_magic=true&ored_clusters=true&items_on_page=20&enable_snippets=true&page=3&hhtmFrom=vacancy_search_list
# Cтраница №5, ссылка: https://ekaterinburg.hh.ru/search/vacancy?text=Python&from=suggest_post&salary=&area=3&no_magic=true&ored_clusters=true&items_on_page=20&enable_snippets=true&page=4&hhtmFrom=vacancy_search_list
# Cтраница №6, ссылка: https://ekaterinburg.hh.ru/search/vacancy?text=Python&from=suggest_post&salary=&area=3&no_magic=true&ored_clusters=true&items_on_page=20&enable_snippets=true&page=5&hhtmFrom=vacancy_search_list
# Cтраница №7, ссылка: https://ekaterinburg.hh.ru/search/vacancy?text=Python&from=suggest_post&salary=&area=3&no_magic=true&ored_clusters=true&items_on_page=20&enable_snippets=true&page=6&hhtmFrom=vacancy_search_list
# Cтраница №8, ссылка: https://ekaterinburg.hh.ru/search/vacancy?text=Python&from=suggest_post&salary=&area=3&no_magic=true&ored_clusters=true&items_on_page=20&enable_snippets=true&page=7&hhtmFrom=vacancy_search_list
# Cтраница №9, ссылка: https://ekaterinburg.hh.ru/search/vacancy?text=Python&from=suggest_post&salary=&area=3&no_magic=true&ored_clusters=true&items_on_page=20&enable_snippets=true&page=8&hhtmFrom=vacancy_search_list
# Парсинг завершен

# %%
len(result)
# Out:
# 178

# %%
result
# Out:
# [{'vacancy_name': 'Бэкенд-разработчик Python (Junior+)',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://ekaterinburg.hh.ru/vacancy/75568055?from=vacancy_search_list&query=Python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Python разработчик',
#   'vacancy_salary': '100\u202f000 – 200\u202f000 руб.',
#   'min_salary': 100000,
#   'max_salary': 200000,
#   'currency_salary': 'руб.',
#   'vacancy_link': 'https://ekaterinburg.hh.ru/vacancy/73712164?from=vacancy_search_list&query=Python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Python-разработчик (внутренние проекты)',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://ekaterinburg.hh.ru/vacancy/75502794?from=vacancy_search_list&query=Python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Бэкенд-разработчик Python (Middle)',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://ekaterinburg.hh.ru/vacancy/75553015?from=vacancy_search_list&query=Python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Программист-математик',
#   'vacancy_salary': '100\u202f000 – 180\u202f000 руб.',
#   'min_salary': 100000,
#   'max_salary': 180000,
#   'currency_salary': 'руб.',
#   'vacancy_link': 'https://ekaterinburg.hh.ru/vacancy/75512767?from=vacancy_search_list&query=Python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Программист Python (Middle)',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://ekaterinburg.hh.ru/vacancy/75568251?from=vacancy_search_list&query=Python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Руководитель группы разработки (Python)',
#   'vacancy_salary': '200\u202f000 – 250\u202f000 руб.',
#   'min_salary': 200000,
#   'max_salary': 250000,
#   'currency_salary': 'руб.',
#   'vacancy_link': 'https://ekaterinburg.hh.ru/vacancy/73817404?from=vacancy_search_list&query=Python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'QA automation engineer (Python)',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://ekaterinburg.hh.ru/vacancy/74830647?from=vacancy_search_list&query=Python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Python developer',
#   'vacancy_salary': 'от 100\u202f000 руб.',
#   'min_salary': 100000,
#   'max_salary': None,
#   'currency_salary': 'руб.',
#   'vacancy_link': 'https://ekaterinburg.hh.ru/vacancy/73860413?from=vacancy_search_list&query=Python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Middle-Senior Python/Django разработчик',
#   'vacancy_salary': '100\u202f000 – 150\u202f000 руб.',
#   'min_salary': 100000,
#   'max_salary': 150000,
#   'currency_salary': 'руб.',
#   'vacancy_link': 'https://ekaterinburg.hh.ru/vacancy/73529910?from=vacancy_search_list&query=Python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Программист Python',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://ekaterinburg.hh.ru/vacancy/74290902?from=vacancy_search_list&query=Python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Python разработчик middle\\senior',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://ekaterinburg.hh.ru/vacancy/73732381?from=vacancy_search_list&query=Python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Junior Data Scientist (Стажер)',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://ekaterinburg.hh.ru/vacancy/73222513?from=vacancy_search_list&query=Python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Ведущий/Старший разработчик Python',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://ekaterinburg.hh.ru/vacancy/74412967?from=vacancy_search_list&query=Python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Python-developer',
#   'vacancy_salary': '150\u202f000 – 220\u202f000 руб.',
#   'min_salary': 150000,
#   'max_salary': 220000,
#   'currency_salary': 'руб.',
#   'vacancy_link': 'https://ekaterinburg.hh.ru/vacancy/72693020?from=vacancy_search_list&query=Python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Начинающий специалист по Python направлению (стажер)',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://ekaterinburg.hh.ru/vacancy/73551924?from=vacancy_search_list&query=Python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Python developer',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://ekaterinburg.hh.ru/vacancy/66934335?from=vacancy_search_list&query=Python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Ведущий Python-developer',
#   'vacancy_salary': '220\u202f000 – 340\u202f000 руб.',
#   'min_salary': 220000,
#   'max_salary': 340000,
#   'currency_salary': 'руб.',
#   'vacancy_link': 'https://ekaterinburg.hh.ru/vacancy/72053651?from=vacancy_search_list&query=Python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Python developer (офис)',
#   'vacancy_salary': 'до 100\u202f000 руб.',
#   'min_salary': None,
#   'max_salary': 100000,
#   'currency_salary': 'руб.',
#   'vacancy_link': 'https://ekaterinburg.hh.ru/vacancy/66112913?from=vacancy_search_list&query=Python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Разработчик витрин данных',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://ekaterinburg.hh.ru/vacancy/70470301?from=vacancy_search_list&query=Python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Computer Vision Engineer (Стажер)',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://ekaterinburg.hh.ru/vacancy/73227833?from=vacancy_search_list&query=Python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Python-разработчик во внутренний каталог сервисов',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://ekaterinburg.hh.ru/vacancy/73523818?from=vacancy_search_list&query=Python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Middle Python (Typescript) Developer',
#   'vacancy_salary': 'от 140\u202f000 руб.',
#   'min_salary': 140000,
#   'max_salary': None,
#   'currency_salary': 'руб.',
#   'vacancy_link': 'https://ekaterinburg.hh.ru/vacancy/73696599?from=vacancy_search_list&query=Python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Middle Python/Go developer (офис)',
#   'vacancy_salary': 'до 200\u202f000 руб.',
#   'min_salary': None,
#   'max_salary': 200000,
#   'currency_salary': 'руб.',
#   'vacancy_link': 'https://ekaterinburg.hh.ru/vacancy/71379712?from=vacancy_search_list&query=Python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Middle Django разработчик',
#   'vacancy_salary': '100\u202f000 – 100\u202f000 руб.',
#   'min_salary': 100000,
#   'max_salary': 100000,
#   'currency_salary': 'руб.',
#   'vacancy_link': 'https://ekaterinburg.hh.ru/vacancy/73433195?from=vacancy_search_list&query=Python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Наставник курса “Профессия Разработчик на Python”',
#   'vacancy_salary': '40\u202f000 – 80\u202f000 руб.',
#   'min_salary': 40000,
#   'max_salary': 80000,
#   'currency_salary': 'руб.',
#   'vacancy_link': 'https://ekaterinburg.hh.ru/vacancy/73318478?from=vacancy_search_list&query=Python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Python QA Automation (Middle)',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://ekaterinburg.hh.ru/vacancy/70666241?from=vacancy_search_list&query=Python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Middle/Senior Python-разработчик в команду Добычи данных',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://ekaterinburg.hh.ru/vacancy/68116288?from=vacancy_search_list&query=Python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Разработчик Ansible',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://ekaterinburg.hh.ru/vacancy/73778732?from=vacancy_search_list&query=Python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Data инженер',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://ekaterinburg.hh.ru/vacancy/72342400?from=vacancy_search_list&query=Python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Senior системный разработчик (python, Linux)',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://ekaterinburg.hh.ru/vacancy/73443159?from=vacancy_search_list&query=Python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Senior/Lead Python-разработчик',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://ekaterinburg.hh.ru/vacancy/74169101?from=vacancy_search_list&query=Python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Backend TeamLead',
#   'vacancy_salary': '200\u202f000 – 350\u202f000 руб.',
#   'min_salary': 200000,
#   'max_salary': 350000,
#   'currency_salary': 'руб.',
#   'vacancy_link': 'https://ekaterinburg.hh.ru/vacancy/73883827?from=vacancy_search_list&query=Python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Аналитик-разработчик',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://ekaterinburg.hh.ru/vacancy/74135458?from=vacancy_search_list&query=Python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'DevOps инженер',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://ekaterinburg.hh.ru/vacancy/75534234?from=vacancy_search_list&query=Python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'IT инженер (linux)',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://ekaterinburg.hh.ru/vacancy/74321123?from=vacancy_search_list&query=Python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Тимлид в команду SQL (юнит DBA)',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://ekaterinburg.hh.ru/vacancy/75451873?from=vacancy_search_list&query=Python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Аналитик данных',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://ekaterinburg.hh.ru/vacancy/70969792?from=vacancy_search_list&query=Python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Specialist DevOps',
#   'vacancy_salary': 'до 280\u202f000 руб.',
#   'min_salary': None,
#   'max_salary': 280000,
#   'currency_salary': 'руб.',
#   'vacancy_link': 'https://ekaterinburg.hh.ru/vacancy/69143099?from=vacancy_search_list&query=Python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Сетевой инженер',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://ekaterinburg.hh.ru/vacancy/75508016?from=vacancy_search_list&query=Python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'DevOps-инженер в сервис транспорта',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://ekaterinburg.hh.ru/vacancy/73327168?from=vacancy_search_list&query=Python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Разработчик на С под Linux (Data Plane)',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://ekaterinburg.hh.ru/vacancy/51000391?from=vacancy_search_list&query=Python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Системный администратор',
#   'vacancy_salary': '80\u202f000 – 85\u202f000 руб.',
#   'min_salary': 80000,
#   'max_salary': 85000,
#   'currency_salary': 'руб.',
#   'vacancy_link': 'https://ekaterinburg.hh.ru/vacancy/75558238?from=vacancy_search_list&query=Python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Администратор Linux',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://ekaterinburg.hh.ru/vacancy/75569457?from=vacancy_search_list&query=Python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'PHP-разработчик',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://ekaterinburg.hh.ru/vacancy/72682316?from=vacancy_search_list&query=Python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Сетевой инженер',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://ekaterinburg.hh.ru/vacancy/73996400?from=vacancy_search_list&query=Python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Инженер-программист',
#   'vacancy_salary': '40\u202f000 – 65\u202f000 руб.',
#   'min_salary': 40000,
#   'max_salary': 65000,
#   'currency_salary': 'руб.',
#   'vacancy_link': 'https://ekaterinburg.hh.ru/vacancy/75501515?from=vacancy_search_list&query=Python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Системный администратор',
#   'vacancy_salary': 'от 60\u202f000 руб.',
#   'min_salary': 60000,
#   'max_salary': None,
#   'currency_salary': 'руб.',
#   'vacancy_link': 'https://ekaterinburg.hh.ru/vacancy/70575345?from=vacancy_search_list&query=Python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Системный аналитик',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://ekaterinburg.hh.ru/vacancy/73988250?from=vacancy_search_list&query=Python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Специалист отдела анализа мониторинга',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://ekaterinburg.hh.ru/vacancy/70421388?from=vacancy_search_list&query=Python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Инженер по информационной безопасности',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://ekaterinburg.hh.ru/vacancy/67498576?from=vacancy_search_list&query=Python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Ведущий системный администратор',
#   'vacancy_salary': '80\u202f000 – 100\u202f000 руб.',
#   'min_salary': 80000,
#   'max_salary': 100000,
#   'currency_salary': 'руб.',
#   'vacancy_link': 'https://ekaterinburg.hh.ru/vacancy/69834335?from=vacancy_search_list&query=Python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'DevOps-инженер',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://ekaterinburg.hh.ru/vacancy/74555675?from=vacancy_search_list&query=Python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Ведущий инженер группы развития и управления ИТ',
#   'vacancy_salary': '65\u202f000 – 85\u202f000 руб.',
#   'min_salary': 65000,
#   'max_salary': 85000,
#   'currency_salary': 'руб.',
#   'vacancy_link': 'https://ekaterinburg.hh.ru/vacancy/71552129?from=vacancy_search_list&query=Python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Специалист по работе с базами данных / BI-аналитик',
#   'vacancy_salary': '60\u202f000 – 70\u202f000 руб.',
#   'min_salary': 60000,
#   'max_salary': 70000,
#   'currency_salary': 'руб.',
#   'vacancy_link': 'https://ekaterinburg.hh.ru/vacancy/74314554?from=vacancy_search_list&query=Python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'DevOps-инженер',
#   'vacancy_salary': 'от 250\u202f000 руб.',
#   'min_salary': 250000,
#   'max_salary': None,
#   'currency_salary': 'руб.',
#   'vacancy_link': 'https://ekaterinburg.hh.ru/vacancy/73575337?from=vacancy_search_list&query=Python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Системный инженер (SOC)',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://ekaterinburg.hh.ru/vacancy/71865102?from=vacancy_search_list&query=Python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Системный администратор Linux (г. Ялта, Республика Крым)',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://ekaterinburg.hh.ru/vacancy/73375053?from=vacancy_search_list&query=Python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'SRE - инженер в PRM',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://ekaterinburg.hh.ru/vacancy/68873612?from=vacancy_search_list&query=Python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Операционный менеджер',
#   'vacancy_salary': 'от 60\u202f000 руб.',
#   'min_salary': 60000,
#   'max_salary': None,
#   'currency_salary': 'руб.',
#   'vacancy_link': 'https://ekaterinburg.hh.ru/vacancy/74346569?from=vacancy_search_list&query=Python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Системный аналитик',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://ekaterinburg.hh.ru/vacancy/74241540?from=vacancy_search_list&query=Python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Разработчик DWH (DATA Engineer)',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://ekaterinburg.hh.ru/vacancy/74172861?from=vacancy_search_list&query=Python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Team Lead продуктовый аналитик в Экстерн',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://ekaterinburg.hh.ru/vacancy/74081523?from=vacancy_search_list&query=Python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'DevOps-инженер',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://ekaterinburg.hh.ru/vacancy/71650841?from=vacancy_search_list&query=Python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Начальник отдела развития инфраструктурных сервисов',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://ekaterinburg.hh.ru/vacancy/72860980?from=vacancy_search_list&query=Python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Руководитель группы разработки (TeamLead)',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://ekaterinburg.hh.ru/vacancy/73982494?from=vacancy_search_list&query=Python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Главный инженер Linux на проекты внедрения',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://ekaterinburg.hh.ru/vacancy/73909464?from=vacancy_search_list&query=Python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Инженер по голосовой связи (Asterisk/Kamailio)',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://ekaterinburg.hh.ru/vacancy/73886904?from=vacancy_search_list&query=Python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Project Manager/менеджер проектов',
#   'vacancy_salary': 'от 80\u202f000 руб.',
#   'min_salary': 80000,
#   'max_salary': None,
#   'currency_salary': 'руб.',
#   'vacancy_link': 'https://ekaterinburg.hh.ru/vacancy/74925429?from=vacancy_search_list&query=Python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Product analyst (machine learning)',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://ekaterinburg.hh.ru/vacancy/73568856?from=vacancy_search_list&query=Python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Преподаватель по направлениям информационные технологии и робототехника',
#   'vacancy_salary': '42\u202f000 – 45\u202f000 руб.',
#   'min_salary': 42000,
#   'max_salary': 45000,
#   'currency_salary': 'руб.',
#   'vacancy_link': 'https://ekaterinburg.hh.ru/vacancy/73711401?from=vacancy_search_list&query=Python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Аналитик / постановщик задач для разработчиков программного обеспечения',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://ekaterinburg.hh.ru/vacancy/73620469?from=vacancy_search_list&query=Python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Руководитель блока моделирования и контроля',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://ekaterinburg.hh.ru/vacancy/71259525?from=vacancy_search_list&query=Python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Инженер-программист АСУ ТП (переезд)',
#   'vacancy_salary': '92\u202f780 – 136\u202f382 руб.',
#   'min_salary': 92780,
#   'max_salary': 136382,
#   'currency_salary': 'руб.',
#   'vacancy_link': 'https://ekaterinburg.hh.ru/vacancy/73559973?from=vacancy_search_list&query=Python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Наставник инженеров лабораторного химического анализа',
#   'vacancy_salary': '100\u202f000 – 120\u202f000 руб.',
#   'min_salary': 100000,
#   'max_salary': 120000,
#   'currency_salary': 'руб.',
#   'vacancy_link': 'https://ekaterinburg.hh.ru/vacancy/73862813?from=vacancy_search_list&query=Python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Ведущий специалист по тестированию на проникновение',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://ekaterinburg.hh.ru/vacancy/71011191?from=vacancy_search_list&query=Python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Senior Photonics Engineer (integrated optics, optoelectronics, lasers)',
#   'vacancy_salary': '80\u202f000 – 120\u202f000 руб.',
#   'min_salary': 80000,
#   'max_salary': 120000,
#   'currency_salary': 'руб.',
#   'vacancy_link': 'https://ekaterinburg.hh.ru/vacancy/73598941?from=vacancy_search_list&query=Python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Ведущий инженер научно-технического отдела',
#   'vacancy_salary': '65\u202f000 – 80\u202f000 руб.',
#   'min_salary': 65000,
#   'max_salary': 80000,
#   'currency_salary': 'руб.',
#   'vacancy_link': 'https://ekaterinburg.hh.ru/vacancy/73366542?from=vacancy_search_list&query=Python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'BI Analyst / BI Аналитик',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://ekaterinburg.hh.ru/vacancy/73592365?from=vacancy_search_list&query=Python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Инженер-конструктор',
#   'vacancy_salary': 'от 50\u202f000 руб.',
#   'min_salary': 50000,
#   'max_salary': None,
#   'currency_salary': 'руб.',
#   'vacancy_link': 'https://ekaterinburg.hh.ru/vacancy/73393262?from=vacancy_search_list&query=Python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Системный аналитик Big Data',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://ekaterinburg.hh.ru/vacancy/73867373?from=vacancy_search_list&query=Python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Системный аналитик RPA',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://ekaterinburg.hh.ru/vacancy/74833292?from=vacancy_search_list&query=Python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Преподаватель по программированию',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://ekaterinburg.hh.ru/vacancy/72276211?from=vacancy_search_list&query=Python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Специалист по добыче данных',
#   'vacancy_salary': 'от 250\u202f000 руб.',
#   'min_salary': 250000,
#   'max_salary': None,
#   'currency_salary': 'руб.',
#   'vacancy_link': 'https://ekaterinburg.hh.ru/vacancy/72352692?from=vacancy_search_list&query=Python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Администратор эксплуатации ИТ платформ (Linux)',
#   'vacancy_salary': 'от 60\u202f000 руб.',
#   'min_salary': 60000,
#   'max_salary': None,
#   'currency_salary': 'руб.',
#   'vacancy_link': 'https://ekaterinburg.hh.ru/vacancy/73232407?from=vacancy_search_list&query=Python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Системный инженер-программист С/С++',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://ekaterinburg.hh.ru/vacancy/50161810?from=vacancy_search_list&query=Python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Инженер-программист С++ (проект REGUL)',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://ekaterinburg.hh.ru/vacancy/72159260?from=vacancy_search_list&query=Python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Инженер систем видеонаблюдения (стажер)',
#   'vacancy_salary': '19\u202f500 – 24\u202f500 руб.',
#   'min_salary': 19500,
#   'max_salary': 24500,
#   'currency_salary': 'руб.',
#   'vacancy_link': 'https://ekaterinburg.hh.ru/vacancy/71852630?from=vacancy_search_list&query=Python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Инженер/Программист микроконтроллеров (стажер)',
#   'vacancy_salary': '19\u202f500 – 24\u202f500 руб.',
#   'min_salary': 19500,
#   'max_salary': 24500,
#   'currency_salary': 'руб.',
#   'vacancy_link': 'https://ekaterinburg.hh.ru/vacancy/71871592?from=vacancy_search_list&query=Python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Системный администратор Linux',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://ekaterinburg.hh.ru/vacancy/74406734?from=vacancy_search_list&query=Python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Java разработчик Naumen SMP',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://ekaterinburg.hh.ru/vacancy/73331737?from=vacancy_search_list&query=Python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Ведущий программист САПР',
#   'vacancy_salary': 'от 100\u202f000 руб.',
#   'min_salary': 100000,
#   'max_salary': None,
#   'currency_salary': 'руб.',
#   'vacancy_link': 'https://ekaterinburg.hh.ru/vacancy/73310816?from=vacancy_search_list&query=Python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Инженер по автоматизации тестирования, Golang, Ozon Bank',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://ekaterinburg.hh.ru/vacancy/74384706?from=vacancy_search_list&query=Python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Специалист службы поддержки с техническими знаниями (Контест)',
#   'vacancy_salary': '15\u202f000 – 39\u202f000 руб.',
#   'min_salary': 15000,
#   'max_salary': 39000,
#   'currency_salary': 'руб.',
#   'vacancy_link': 'https://ekaterinburg.hh.ru/vacancy/48224442?from=vacancy_search_list&query=Python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Разработчик бэкенда в Путешествия',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://ekaterinburg.hh.ru/vacancy/70824403?from=vacancy_search_list&query=Python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Специалист службы поддержки с техническими знаниями (TOOLS)',
#   'vacancy_salary': '15\u202f000 – 39\u202f000 руб.',
#   'min_salary': 15000,
#   'max_salary': 39000,
#   'currency_salary': 'руб.',
#   'vacancy_link': 'https://ekaterinburg.hh.ru/vacancy/73595106?from=vacancy_search_list&query=Python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'IT рекрутер',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://ekaterinburg.hh.ru/vacancy/74365733?from=vacancy_search_list&query=Python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'QA-инженер в команду Otello',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://ekaterinburg.hh.ru/vacancy/71896897?from=vacancy_search_list&query=Python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Ведущий аналитик',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://ekaterinburg.hh.ru/vacancy/74344036?from=vacancy_search_list&query=Python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Системный аналитик на проект "Ценообразование"',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://ekaterinburg.hh.ru/vacancy/74350210?from=vacancy_search_list&query=Python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'QA Automation engineer',
#   'vacancy_salary': 'от 100\u202f000 руб.',
#   'min_salary': 100000,
#   'max_salary': None,
#   'currency_salary': 'руб.',
#   'vacancy_link': 'https://ekaterinburg.hh.ru/vacancy/43670261?from=vacancy_search_list&query=Python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Системный аналитик',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://ekaterinburg.hh.ru/vacancy/49454824?from=vacancy_search_list&query=Python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Ведущий системный аналитик',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://ekaterinburg.hh.ru/vacancy/67546181?from=vacancy_search_list&query=Python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Teamlead QA Automation engineer',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://ekaterinburg.hh.ru/vacancy/43670929?from=vacancy_search_list&query=Python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Бизнес-аналитик в отдел разработки',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://ekaterinburg.hh.ru/vacancy/69561454?from=vacancy_search_list&query=Python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Руководитель группы тестирования',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://ekaterinburg.hh.ru/vacancy/39014647?from=vacancy_search_list&query=Python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Разработчик ETL',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://ekaterinburg.hh.ru/vacancy/71786191?from=vacancy_search_list&query=Python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Scala/Java разработчик (Hadoop)',
#   'vacancy_salary': '150\u202f000 – 200\u202f000 руб.',
#   'min_salary': 150000,
#   'max_salary': 200000,
#   'currency_salary': 'руб.',
#   'vacancy_link': 'https://ekaterinburg.hh.ru/vacancy/71750200?from=vacancy_search_list&query=Python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Инженер по информационной безопасности, Инфраструктура',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://ekaterinburg.hh.ru/vacancy/71680000?from=vacancy_search_list&query=Python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Руководитель отдела системного анализа',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://ekaterinburg.hh.ru/vacancy/69559421?from=vacancy_search_list&query=Python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Руководитель отдела бизнес-анализа',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://ekaterinburg.hh.ru/vacancy/69561874?from=vacancy_search_list&query=Python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Middle QA Engineer',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://ekaterinburg.hh.ru/vacancy/74236349?from=vacancy_search_list&query=Python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Администратор файловых ресурсов',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://ekaterinburg.hh.ru/vacancy/73093358?from=vacancy_search_list&query=Python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Руководитель IT проектов',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://ekaterinburg.hh.ru/vacancy/73571356?from=vacancy_search_list&query=Python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Android-разработчик в Рекламную сеть Яндекса',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://ekaterinburg.hh.ru/vacancy/74195151?from=vacancy_search_list&query=Python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Аналитик данных',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://ekaterinburg.hh.ru/vacancy/74130374?from=vacancy_search_list&query=Python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Kubernetes SRE engineer',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://ekaterinburg.hh.ru/vacancy/74147906?from=vacancy_search_list&query=Python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Инженер технической поддержки Naumen Erudite',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://ekaterinburg.hh.ru/vacancy/72951328?from=vacancy_search_list&query=Python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'QA Engineer (Backend)',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://ekaterinburg.hh.ru/vacancy/67329350?from=vacancy_search_list&query=Python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'IOS-разработчик в Рекламную сеть Яндекса',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://ekaterinburg.hh.ru/vacancy/74195153?from=vacancy_search_list&query=Python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Ведущий менеджер (Сервис аналитики и оценки эффективности КУ ТМК2U)',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://ekaterinburg.hh.ru/vacancy/74087911?from=vacancy_search_list&query=Python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Аналитик/Ведущий аналитик DWH',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://ekaterinburg.hh.ru/vacancy/73035476?from=vacancy_search_list&query=Python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Инженер SRE/ DevOps-инженер',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://ekaterinburg.hh.ru/vacancy/73979474?from=vacancy_search_list&query=Python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Менеджер IT-проектов внедрения в Контур.Налоговый мониторинг',
#   'vacancy_salary': '100\u202f000 – 160\u202f000 руб.',
#   'min_salary': 100000,
#   'max_salary': 160000,
#   'currency_salary': 'руб.',
#   'vacancy_link': 'https://ekaterinburg.hh.ru/vacancy/72674376?from=vacancy_search_list&query=Python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Аналитик сайта',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://ekaterinburg.hh.ru/vacancy/73988126?from=vacancy_search_list&query=Python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Системный аналитик',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://ekaterinburg.hh.ru/vacancy/74011518?from=vacancy_search_list&query=Python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Администратор Linux AD',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://ekaterinburg.hh.ru/vacancy/71888473?from=vacancy_search_list&query=Python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Инженер СХД',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://ekaterinburg.hh.ru/vacancy/72682810?from=vacancy_search_list&query=Python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Эксперт СРК',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://ekaterinburg.hh.ru/vacancy/72682680?from=vacancy_search_list&query=Python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Руководитель направления оценки бизнес-инициатив',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://ekaterinburg.hh.ru/vacancy/72747737?from=vacancy_search_list&query=Python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Технические специалист / Интегратор (CPA)',
#   'vacancy_salary': 'до 70\u202f000 руб.',
#   'min_salary': None,
#   'max_salary': 70000,
#   'currency_salary': 'руб.',
#   'vacancy_link': 'https://ekaterinburg.hh.ru/vacancy/71269281?from=vacancy_search_list&query=Python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Разработчик .NET +(либо) Java+(либо) Python',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://ekaterinburg.hh.ru/vacancy/73905022?from=vacancy_search_list&query=Python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Технолог-аналитик (junior+)',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://ekaterinburg.hh.ru/vacancy/73191268?from=vacancy_search_list&query=Python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Администратор Linux',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://ekaterinburg.hh.ru/vacancy/69520350?from=vacancy_search_list&query=Python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Системный инженер',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://ekaterinburg.hh.ru/vacancy/73895459?from=vacancy_search_list&query=Python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Инженер сопровождения инфраструктуры/Junior DevOps Engineer',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://ekaterinburg.hh.ru/vacancy/73863724?from=vacancy_search_list&query=Python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Junior DevOps',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://ekaterinburg.hh.ru/vacancy/73825237?from=vacancy_search_list&query=Python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Руководитель группы аналитики',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://ekaterinburg.hh.ru/vacancy/70987987?from=vacancy_search_list&query=Python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Инженер DevOps (проект реестр справочников)',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://ekaterinburg.hh.ru/vacancy/73859716?from=vacancy_search_list&query=Python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Системный администратор Linux',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://ekaterinburg.hh.ru/vacancy/73825857?from=vacancy_search_list&query=Python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'DevOps Engineer',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://ekaterinburg.hh.ru/vacancy/69309379?from=vacancy_search_list&query=Python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Системный аналитик сопровождения Naumen Erudite',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://ekaterinburg.hh.ru/vacancy/71938385?from=vacancy_search_list&query=Python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Backend разработчик С++ в команду Транспорта',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://ekaterinburg.hh.ru/vacancy/72747030?from=vacancy_search_list&query=Python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'С++ разработчик в группу качества коммерческих сценариев',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://ekaterinburg.hh.ru/vacancy/73820802?from=vacancy_search_list&query=Python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Full-stack Yii2/PHP-разработчик',
#   'vacancy_salary': 'до 200\u202f000 руб.',
#   'min_salary': None,
#   'max_salary': 200000,
#   'currency_salary': 'руб.',
#   'vacancy_link': 'https://ekaterinburg.hh.ru/vacancy/73791090?from=vacancy_search_list&query=Python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Педагог дополнительного образования (робототехника)',
#   'vacancy_salary': 'от 25\u202f000 руб.',
#   'min_salary': 25000,
#   'max_salary': None,
#   'currency_salary': 'руб.',
#   'vacancy_link': 'https://ekaterinburg.hh.ru/vacancy/73790376?from=vacancy_search_list&query=Python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'DevOps - инженер',
#   'vacancy_salary': 'от 150\u202f000 руб.',
#   'min_salary': 150000,
#   'max_salary': None,
#   'currency_salary': 'руб.',
#   'vacancy_link': 'https://ekaterinburg.hh.ru/vacancy/73721806?from=vacancy_search_list&query=Python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Тестировщик / QA (web, python)',
#   'vacancy_salary': 'от 75\u202f000 руб.',
#   'min_salary': 75000,
#   'max_salary': None,
#   'currency_salary': 'руб.',
#   'vacancy_link': 'https://ekaterinburg.hh.ru/vacancy/73721223?from=vacancy_search_list&query=Python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Frontend-разработчик (Angular)',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://ekaterinburg.hh.ru/vacancy/73317351?from=vacancy_search_list&query=Python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Junior программист 1С',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://ekaterinburg.hh.ru/vacancy/73779536?from=vacancy_search_list&query=Python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Аналитик-аудитор',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://ekaterinburg.hh.ru/vacancy/73722292?from=vacancy_search_list&query=Python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Инженер СХД',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://ekaterinburg.hh.ru/vacancy/72456482?from=vacancy_search_list&query=Python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Начальник Регионального центра развития «Санкт-Петербург»',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://ekaterinburg.hh.ru/vacancy/73826214?from=vacancy_search_list&query=Python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Инженер внедрения систем мониторинга информационной безопасности (SIEM)',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://ekaterinburg.hh.ru/vacancy/51627482?from=vacancy_search_list&query=Python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Администратор IDM',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://ekaterinburg.hh.ru/vacancy/71806572?from=vacancy_search_list&query=Python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Инженер по узлам пакетной коммутации (PS Core)',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://ekaterinburg.hh.ru/vacancy/68956247?from=vacancy_search_list&query=Python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'ML-инженер',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://ekaterinburg.hh.ru/vacancy/72111824?from=vacancy_search_list&query=Python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Инженер-разработчик',
#   'vacancy_salary': '50\u202f000 – 93\u202f000 руб.',
#   'min_salary': 50000,
#   'max_salary': 93000,
#   'currency_salary': 'руб.',
#   'vacancy_link': 'https://ekaterinburg.hh.ru/vacancy/72151832?from=vacancy_search_list&query=Python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Начинающий специалист по DevOps направлению (стажер)',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://ekaterinburg.hh.ru/vacancy/73551792?from=vacancy_search_list&query=Python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'DevOps инженер',
#   'vacancy_salary': 'от 170\u202f000 руб.',
#   'min_salary': 170000,
#   'max_salary': None,
#   'currency_salary': 'руб.',
#   'vacancy_link': 'https://ekaterinburg.hh.ru/vacancy/68268250?from=vacancy_search_list&query=Python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'PHP-разработчик с функциями технической поддержки',
#   'vacancy_salary': 'от 150\u202f000 руб.',
#   'min_salary': 150000,
#   'max_salary': None,
#   'currency_salary': 'руб.',
#   'vacancy_link': 'https://ekaterinburg.hh.ru/vacancy/73578065?from=vacancy_search_list&query=Python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Системный администратор Linux',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://ekaterinburg.hh.ru/vacancy/72480824?from=vacancy_search_list&query=Python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Начинающий специалист по направлению Unity (стажер)',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://ekaterinburg.hh.ru/vacancy/73551769?from=vacancy_search_list&query=Python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Начинающий специалист по .NET направлению (стажер)',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://ekaterinburg.hh.ru/vacancy/73551938?from=vacancy_search_list&query=Python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'DevOps-инженер',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://ekaterinburg.hh.ru/vacancy/69779705?from=vacancy_search_list&query=Python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Инженер DevOps в инфраструктурную команду',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://ekaterinburg.hh.ru/vacancy/73436867?from=vacancy_search_list&query=Python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'IT рекрутер',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://ekaterinburg.hh.ru/vacancy/73838114?from=vacancy_search_list&query=Python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Unity разработчик (Middle)',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://ekaterinburg.hh.ru/vacancy/73838122?from=vacancy_search_list&query=Python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Старший разработчик в отдел облачной инфраструктуры',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://ekaterinburg.hh.ru/vacancy/73438332?from=vacancy_search_list&query=Python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Эксперт по технологическим вопросам 1С (стажер)',
#   'vacancy_salary': '120\u202f000 – 140\u202f000 руб.',
#   'min_salary': 120000,
#   'max_salary': 140000,
#   'currency_salary': 'руб.',
#   'vacancy_link': 'https://ekaterinburg.hh.ru/vacancy/71773981?from=vacancy_search_list&query=Python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Специалист службы поддержки с техническими знаниями (Волкер)',
#   'vacancy_salary': '15\u202f000 – 39\u202f000 руб.',
#   'min_salary': 15000,
#   'max_salary': 39000,
#   'currency_salary': 'руб.',
#   'vacancy_link': 'https://ekaterinburg.hh.ru/vacancy/73493046?from=vacancy_search_list&query=Python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Тимлид в команду разработки на Java',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://ekaterinburg.hh.ru/vacancy/73443927?from=vacancy_search_list&query=Python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Системный администратор',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://ekaterinburg.hh.ru/vacancy/73309666?from=vacancy_search_list&query=Python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Технический писатель',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://ekaterinburg.hh.ru/vacancy/73379908?from=vacancy_search_list&query=Python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Главный специалист аналитик (закупки)',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://ekaterinburg.hh.ru/vacancy/72320607?from=vacancy_search_list&query=Python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Frontend-разработчик',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://ekaterinburg.hh.ru/vacancy/73725386?from=vacancy_search_list&query=Python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Тестировщик/QA-инженер',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://ekaterinburg.hh.ru/vacancy/73849621?from=vacancy_search_list&query=Python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Педагог в онлайн-школу программирования',
#   'vacancy_salary': 'от 30\u202f000 руб.',
#   'min_salary': 30000,
#   'max_salary': None,
#   'currency_salary': 'руб.',
#   'vacancy_link': 'https://ekaterinburg.hh.ru/vacancy/73378698?from=vacancy_search_list&query=Python',
#   'vacancy_source': 'hh.ru'}]
