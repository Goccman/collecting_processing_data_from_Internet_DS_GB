# %% [markdown]
# # Система управления базами данных MongoDB в Python

# %%
from pprint import pprint
from bs4 import BeautifulSoup as bs
import requests
from time import sleep

# %% [markdown]
# Парсинг с применением библиотеки Requests, и обработкой полученной структуры — с помощью библиотеки Beautiful Soup. Парсинг вакансий на сайте hh.ru в регионе Екатеринбург по ключевому запросу "Python", с отображением информации о названии объявления, размера ЗП с отображением вилки от минимальной до максимальной, валютой ЗП, ссылкой на вакансию.

# %%
USER_AGENT = 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/104.0.0.0 Safari/537.36'

URL_FIRST_PAGE_HH = 'https://ekaterinburg.hh.ru/search/vacancy?text=Python&from=suggest_post&salary=&area=3&no_magic=true&ored_clusters=true&items_on_page=20&enable_snippets=true'

# %%
headers = {
    'User-Agent': USER_AGENT,
}

# %%
def parse_hh(url_page, headers, result=[], index_page=1):
    response = requests.get(url_page, headers=headers)
    if response.status_code != 200:
      print('Парсинг завершен')
      return result
    else:
      print('Cтраница №%d, ссылка: %s'%(index_page, response.url))

    dom = bs(response.content, 'html.parser')
    vacancies = dom.find_all('div', {'class': 'vacancy-serp-item__layout'})
    for vacancy in vacancies:
      result.append(parse_vacancy_hh(vacancy))

    link_next_page = dom.find('a', {'data-qa': 'pager-next'})
    if link_next_page:
      link_next_page =  'https://ekaterinburg.hh.ru' + link_next_page['href']
    else:
      print('Парсинг завершен')
      return result

    result = parse_hh(link_next_page, headers, result, index_page+1)   
    return result
     
def parse_vacancy_hh(dom_vacancy):
  sleep(0.1)
  vacancy_name = dom_vacancy.find('a').text

  vacancy_salary = dom_vacancy.find('span', {'class', 'bloko-header-section-3'})
  if vacancy_salary:
    vacancy_salary = vacancy_salary.text
    min_salary, max_salary, currency_salary = clean_salary(vacancy_salary)
  else:
    min_salary, max_salary, currency_salary = None, None, None

  vacancy_link = dom_vacancy.find('a')['href']
  
  return {
      'vacancy_name': vacancy_name,
      'vacancy_salary': vacancy_salary,
      'min_salary': min_salary,
      'max_salary': max_salary,
      'currency_salary': currency_salary,
      'vacancy_link': vacancy_link,
      'vacancy_source': 'hh.ru',
  }

def clean_salary(vacancy_salary_text, min_salary=None, max_salary=None, currency_salary=None):
  list_salary = vacancy_salary_text.replace('\u202f', '').split()
  for i in range(len(list_salary) - 1):
    if list_salary[i] == 'от':
      min_salary = int(list_salary[i + 1])
    elif list_salary[i] == 'до':
      max_salary = int(list_salary[i + 1])
    elif list_salary[i] == '–':
      min_salary = int(list_salary[i - 1])
      max_salary = int(list_salary[i + 1])
  currency_salary = list_salary[-1]

  return min_salary, max_salary, currency_salary

# %%
result = parse_hh(URL_FIRST_PAGE_HH, headers)
# Out:
# Cтраница №1, ссылка: https://ekaterinburg.hh.ru/search/vacancy?text=Python&from=suggest_post&salary=&area=3&no_magic=true&ored_clusters=true&items_on_page=20&enable_snippets=true
# Cтраница №2, ссылка: https://ekaterinburg.hh.ru/search/vacancy?text=Python&from=suggest_post&salary=&area=3&no_magic=true&ored_clusters=true&items_on_page=20&enable_snippets=true&page=1&hhtmFrom=vacancy_search_list
# Cтраница №3, ссылка: https://ekaterinburg.hh.ru/search/vacancy?text=Python&from=suggest_post&salary=&area=3&no_magic=true&ored_clusters=true&items_on_page=20&enable_snippets=true&page=2&hhtmFrom=vacancy_search_list
# Cтраница №4, ссылка: https://ekaterinburg.hh.ru/search/vacancy?text=Python&from=suggest_post&salary=&area=3&no_magic=true&ored_clusters=true&items_on_page=20&enable_snippets=true&page=3&hhtmFrom=vacancy_search_list
# Cтраница №5, ссылка: https://ekaterinburg.hh.ru/search/vacancy?text=Python&from=suggest_post&salary=&area=3&no_magic=true&ored_clusters=true&items_on_page=20&enable_snippets=true&page=4&hhtmFrom=vacancy_search_list
# Cтраница №6, ссылка: https://ekaterinburg.hh.ru/search/vacancy?text=Python&from=suggest_post&salary=&area=3&no_magic=true&ored_clusters=true&items_on_page=20&enable_snippets=true&page=5&hhtmFrom=vacancy_search_list
# Cтраница №7, ссылка: https://ekaterinburg.hh.ru/search/vacancy?text=Python&from=suggest_post&salary=&area=3&no_magic=true&ored_clusters=true&items_on_page=20&enable_snippets=true&page=6&hhtmFrom=vacancy_search_list
# Cтраница №8, ссылка: https://ekaterinburg.hh.ru/search/vacancy?text=Python&from=suggest_post&salary=&area=3&no_magic=true&ored_clusters=true&items_on_page=20&enable_snippets=true&page=7&hhtmFrom=vacancy_search_list
# Cтраница №9, ссылка: https://ekaterinburg.hh.ru/search/vacancy?text=Python&from=suggest_post&salary=&area=3&no_magic=true&ored_clusters=true&items_on_page=20&enable_snippets=true&page=8&hhtmFrom=vacancy_search_list
# Cтраница №10, ссылка: https://ekaterinburg.hh.ru/search/vacancy?text=Python&from=suggest_post&salary=&area=3&no_magic=true&ored_clusters=true&items_on_page=20&enable_snippets=true&page=9&hhtmFrom=vacancy_search_list
# Парсинг завершен

# %%
len(result)
# Out:
# 195

# %% [markdown]
# # Установим mongo сервер и клиент

# %%
# !apt install mongodb > log
# Out:
# WARNING: apt does not have a stable CLI interface. Use with caution in scripts.

# %%
# !service mongodb start
# Out:
#  * Starting database mongodb
#    ...done.

# %%
# !pip install pymongo
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: pymongo in /usr/local/lib/python3.8/dist-packages (4.3.3)
# Requirement already satisfied: dnspython<3.0.0,>=1.16.0 in /usr/local/lib/python3.8/dist-packages (from pymongo) (2.2.1)

# %% [markdown]
# # Запишем данные в базу

# %%
from pymongo import MongoClient

# %%
client = MongoClient()

# %%
db = client.vacancies_python_hh

# %%
collection_vacancies_hh_ru = db.hh_ru

# %%
def cheak_and_save_vacancies_in_db(vacancies):
  for vacancy in vacancies:
    if not len(list(collection_vacancies_hh_ru.find({'vacancy_link': vacancy['vacancy_link']}))):
      collection_vacancies_hh_ru.insert_one(vacancy)

# %%
cheak_and_save_vacancies_in_db(result)

# %%
result_find = list(collection_vacancies_hh_ru.find())

# %%
len(result_find)
# Out:
# 195

# %% [markdown]
# # Выведем вакансии с максимальной заработной платой больше 200 000 руб

# %%
for document in collection_vacancies_hh_ru.find({'max_salary': {'$gt': 200000}}):
  pprint(document)
# Out:
# {'_id': ObjectId('63c02cd68069150cc74e1e0e'),
#  'currency_salary': 'руб.',
#  'max_salary': 220000,
#  'min_salary': 150000,
#  'vacancy_link': 'https://ekaterinburg.hh.ru/vacancy/72693020?from=vacancy_search_list&query=Python',
#  'vacancy_name': 'Python-developer',
#  'vacancy_salary': '150\u202f000 – 220\u202f000 руб.',
#  'vacancy_source': 'hh.ru'}
# {'_id': ObjectId('63c02cd68069150cc74e1e10'),
#  'currency_salary': 'руб.',
#  'max_salary': 340000,
#  'min_salary': 220000,
#  'vacancy_link': 'https://ekaterinburg.hh.ru/vacancy/72053651?from=vacancy_search_list&query=Python',
#  'vacancy_name': 'Ведущий Python-developer',
#  'vacancy_salary': '220\u202f000 – 340\u202f000 руб.',
#  'vacancy_source': 'hh.ru'}
# {'_id': ObjectId('63c02cd68069150cc74e1e12'),
#  'currency_salary': 'руб.',
#  'max_salary': 250000,
#  'min_salary': 200000,
#  'vacancy_link': 'https://ekaterinburg.hh.ru/vacancy/73817404?from=vacancy_search_list&query=Python',
#  'vacancy_name': 'Руководитель группы разработки (Python)',
#  'vacancy_salary': '200\u202f000 – 250\u202f000 руб.',
#  'vacancy_source': 'hh.ru'}
# {'_id': ObjectId('63c02cd68069150cc74e1e21'),
#  'currency_salary': 'руб.',
#  'max_salary': 350000,
#  'min_salary': 200000,
#  'vacancy_link': 'https://ekaterinburg.hh.ru/vacancy/73883827?from=vacancy_search_list&query=Python',
#  'vacancy_name': 'Backend TeamLead',
#  'vacancy_salary': '200\u202f000 – 350\u202f000 руб.',
#  'vacancy_source': 'hh.ru'}
# {'_id': ObjectId('63c02cd68069150cc74e1e37'),
#  'currency_salary': 'руб.',
#  'max_salary': 213000,
#  'min_salary': 71000,
#  'vacancy_link': 'https://ekaterinburg.hh.ru/vacancy/75656026?from=vacancy_search_list&query=Python',
#  'vacancy_name': 'Программист 1С',
#  'vacancy_salary': '71\u202f000 – 213\u202f000 руб.',
#  'vacancy_source': 'hh.ru'}
# {'_id': ObjectId('63c02cd68069150cc74e1e59'),
#  'currency_salary': 'руб.',
#  'max_salary': 280000,
#  'min_salary': None,
#  'vacancy_link': 'https://ekaterinburg.hh.ru/vacancy/69143099?from=vacancy_search_list&query=Python',
#  'vacancy_name': 'Specialist DevOps',
#  'vacancy_salary': 'до 280\u202f000 руб.',
#  'vacancy_source': 'hh.ru'}
